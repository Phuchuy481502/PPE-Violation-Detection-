# %%
import git
# !rm -rf /kaggle/working/sample

# !rm -rf /kaggle%cd /kaggle/working/working/trained_model
git.Repo.clone_from('https://github.com/Beeditor04/CS406-PPE-detection.git', '/kaggle/working/sample')
# Out:
# <git.repo.base.Repo '/kaggle/working/sample/.git'>

# %%
pip install pycocotools
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.8/427.8 kB 9.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cd /kaggle/working/
# Out:
# /kaggle/working

# %%
import os
import shutil

# Define the content of the YAML file
yaml_content = """
names:
- Hardhat
- NO-Hardhat
- Safety Vest
- NO-Safety Vest
- Gloves
- No-Gloves
- Person
nc: 7

train: /train/images
val: /valid/images
test: /test/images
"""

# Define the file paths
file_path = "data-ppe.yaml"
destination_path = "/kaggle/working/data-ppe.yaml"

# Write the content to the file
with open(file_path, "w") as file:
    file.write(yaml_content)

# Move the file to the desired directory
shutil.move(file_path, destination_path)

print(f"File moved to {destination_path}")
# Out:
# File moved to /kaggle/working/data-ppe.yaml

# %%
# !python /kaggle/working/sample/scripts/train_faster_rcnn.py \
                    --data_dir "/kaggle/input/ppe-detection-cs406/dataset/" \
                    --batch_size 4 \
                    --epochs 100 \
                    --eval_every 5 \
                    --iter_every 100 \
                    --num_classes 7 \
                    --yaml {destination_path} \
                    --lr 0.01 \
                    --resize 640 \
                    --is_aug 0
# Out:
# Loading dataset...
# Downloading: "https://download.pytorch.org/models/fasterrcnn_mobilenet_v3_large_fpn-fb6a3cc7.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_mobilenet_v3_large_fpn-fb6a3cc7.pth
# 100%|██████████████████████████████████████| 74.2M/74.2M [00:00<00:00, 94.6MB/s]
# Training started.
# Device:  cuda
# Number of classes:  7
# Number of epochs:  100
# Batch size:  4
# Dataset length:  4895
# Evaluation every:  5
# Epoch:[1/100]	Iter:[1/1224]	cls_loss:2.2528	box_loss:0.2325	obj_loss:0.3142
# Epoch:[1/100]	Iter:[100/1224]	cls_loss:0.3952	box_loss:0.3611	obj_loss:0.2911
# Epoch:[1/100]	Iter:[200/1224]	cls_loss:0.1243	box_loss:0.1065	obj_loss:0.1002
# Epoch:[1/100]	Iter:[300/1224]	cls_loss:0.3288	box_loss:0.3190	obj_loss:0.0527
# Epoch:[1/100]	Iter:[400/1224]	cls_loss:0.1417	box_loss:0.2195	obj_loss:0.0626
# Epoch:[1/100]	Iter:[500/1224]	cls_loss:0.2516	box_loss:0.2045	obj_loss:0.0509
# Epoch:[1/100]	Iter:[600/1224]	cls_loss:0.4018	box_loss:0.3036	obj_loss:0.1292
# ...
